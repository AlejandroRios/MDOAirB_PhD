# %%
import pandas as pd
import os
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import numpy as np

# %%
path = os.getcwd()
print(path)
input = pd.read_csv(path + "/Results/analysis_single_input_1-new.csv")
output = pd.read_csv(path + "/Results/analysis_single_output_1-new.csv")
# Out:
# c:\Users\aarc8\Documents\github\MDOAirB_base\framework

# %%
input.head()
# Out:
#    WingArea          x1    x2    x3    x4    x5     x6   x7      x8    x9  \
# 0     142.5  135.692308  30.0  25.0 -2.25  38.5  250.0  6.0  3000.0  55.0
#
#    FanDiameter   x11     x12   x13      x14   x15
# 0         25.0  27.0  1350.0  15.0  38000.0  78.0

# %%
output.head()
# Out:
#             MTOW           DOC    fuel_mass  total_mission_flight_time  mach  \
# 0  128565.653552  14006.745205  6838.284369                 217.391437  0.82
#
#    passenger_capacity       SAR  landing_field_length_computed  \
# 0               243.0  8.547855                    2249.038782
#
#    takeoff_field_length_computed  app_speed  ...  \
# 0                    1754.143013  78.383764  ...
#
#                                                 mass  \
# 0  [105937.67708072 105937.6770807  105937.677080...
#
#                                                 time  \
# 0  [0.00000000e+00 1.11630830e-10 2.23261659e-10 ...
#
#                                                  sfc  \
# 0  [ 0.47316835  0.47316835  0.47316835  0.473168...
#
#                                               thrust  \
# 0  [1.46057830e+05 1.46057830e+05 1.46057830e+05 ...
#
#                                               mach.1  \
# 0  [0.43446873 0.43446873 0.43446873 0.43446879 0...
#
# ...

# %%
distance = output['distance'].apply(lambda x:
                           np.fromstring(
                               x.replace('\n', '')
                                .replace('[', '')
                                .replace(']', '')
                                .replace('  ', ' '), sep=' '))[0]
mass = output['mass'].apply(lambda x:
                           np.fromstring(
                               x.replace('\n', '')
                                .replace('[', '')
                                .replace(']', '')
                                .replace('  ', ' '), sep=' '))[0]
altitude = output['altitude'].apply(lambda x:
                           np.fromstring(
                               x.replace('\n', '')
                                .replace('[', '')
                                .replace(']', '')
                                .replace('  ', ' '), sep=' '))[0]
time = output['time'].apply(lambda x:
                           np.fromstring(
                               x.replace('\n', '')
                                .replace('[', '')
                                .replace(']', '')
                                .replace('  ', ' '), sep=' '))[0]
LoD = output['LoD'].apply(lambda x:
                           np.fromstring(
                               x.replace('\n', '')
                                .replace('[', '')
                                .replace(']', '')
                                .replace('  ', ' '), sep=' '))[0]
sfc = output['sfc'].apply(lambda x:
                           np.fromstring(
                               x.replace('\n', '')
                                .replace('[', '')
                                .replace(']', '')
                                .replace('  ', ' '), sep=' '))[0]
CL = output['CL'].apply(lambda x:
                           np.fromstring(
                               x.replace('\n', '')
                                .replace('[', '')
                                .replace(']', '')
                                .replace('  ', ' '), sep=' '))[0]
CD = output['CD'].apply(lambda x:
                           np.fromstring(
                               x.replace('\n', '')
                                .replace('[', '')
                                .replace(']', '')
                               .replace('  ', ' '), sep=' '))[0]
mach = output['mach.1'].apply(lambda x:
                        np.fromstring(
                            x.replace('\n', '')
                            .replace('[', '')
                            .replace(']', '')
                            .replace('  ', ' '), sep=' '))[0]
thrust = output['thrust'].apply(lambda x:
                              np.fromstring(
                                  x.replace('\n', '')
                                  .replace('[', '')
                                  .replace(']', '')
                                  .replace('  ', ' '), sep=' '))[0]
throttle = output['throttle'].apply(lambda x:
                              np.fromstring(
                                  x.replace('\n', '')
                                  .replace('[', '')
                                  .replace(']', '')
                                  .replace('  ', ' '), sep=' '))[0]

# %%
plt.plot(distance, time)
plt.ylabel("Time (min)")
plt.xlabel("Distance (m)")
plt.grid()
plt.show()

# %%
plt.plot(distance,altitude)
plt.grid()
plt.show()

# %%
print(distance[-1]*0.000539957)
print(time[-1])
print(mass[0]-mass[-1])
print(altitude[0])
print(altitude[-1])
# Out:
# 0.40216313666810594
# 109.491437
# 6477.133196939991
# 1500.0
# 558.82557991

# %%
plt.plot(distance, LoD)
plt.grid()
plt.show()

# %%
plt.plot(distance, sfc)
plt.grid()
plt.show()

# %%
plt.plot(distance, CL)
plt.grid()
plt.show()

# %%
plt.plot(distance, CD)
plt.grid()
plt.show()

# %%
plt.plot(distance, mach)
plt.grid()
plt.show()

# %%
plt.plot(distance, thrust)
plt.grid()
plt.show()

# %%
plt.plot(distance, throttle*100)
plt.grid()
plt.ylabel("Throttle position (%)")
plt.xlabel("Distance (m)")
plt.show()

# %%
plt.plot(time,altitude)
plt.grid()
plt.show()
